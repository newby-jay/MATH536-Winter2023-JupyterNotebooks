# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
from ipywidgets import interact
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # These problems are for practice only; you do not need to turn in your work
# ## This should not be taken as an indication of the number of questions that will appear the actual midterm

# %% [markdown]
# # Q1: Finite differences
# Let $f(x)$ be infinitely differentiable on a neighborhood containing $x=a$. Derive a general formula for an $p$th order accurate finite difference approximation for $f^{(k)}(a)$.

# %% [markdown]
# # Q2: Finite differences and polynomials
# Show that an $p$th order accurate finite difference approximation of the $k$th deriviative is exact for any polynomial of degree $m$ where $m < p+k$.

# %% [markdown]
# # Q3: truncation error, 2-norm stability, convergence
# Consider the boundary value problem
# $$ u''(x) = f(x), \quad x \in (a, b),$$
# with Dirichlet boundary conditions
# $$ u(a) = \alpha, \qquad u(b) = \beta. $$
# Discretize the interval $(a, b)$ into $m+2$ equally spaced points $x_j$, $j=0, 1, \ldots, m+1$. The separation between points is $h = 1/(m+1)$. Let $U_j = u(x_j)$ so that $U_0 = u(a) = \alpha$ and $U_{m+1} = u(b) = \beta$. The unknown portion of the numerical solution is $U_j$, $j = 1, \ldots m$, which satisfies
# $$ \frac{1}{h^2}(U_{j-1} - 2 U_j + U_{j+1}) = f(x_j), \quad j=1,\ldots, m .$$
#
# ## A
# Show that the finite difference for the second derivative used in the above scheme is second order accurate.
#
# ## B
# Reformulate the equation for the unknown values of $U_j$ as a linear system of equation in matrix form (i.e., $AU = F$). Make sure to specify the elements and shape of the matrix $A$, the unknown vector $U$, and the right hand side $F$.
#
# ## C
# Show that the local truncation error is $O(h^2)$.
#
# ## D
# Show the following
#   1. There exists an $h_0 > 0$ such that $A$ is nonsingular for all $h \in (0, h_0)$
#   2. $\Vert A^{-1} \Vert_2 \leq C$ for all $h \in (0, h_0)$, where $C$ is independent of $h$.
#
# ## E
# Using the results from parts C and D, show that the 2-norm global error converges as $h\to 0^+$.
#
# ## F
# Extending your result from part E, show that the 2-norm global error is $O(h^2)$

# %% [markdown]
# # Q4: Norm equivalence
# Using the inequality $\Vert x \Vert_{\infty} \leq \Vert x \Vert_{2} \leq \sqrt{n}\Vert x \Vert_{\infty} $, for $x\in \mathbb{R}^n$, explain why 2-norm stability is not equivalent to $\infty$-norm stability in terms of what each implies about convergence of the global error.

# %% [markdown]
# # Q4: Elliptic problems and iterative solvers
# Consider the elliptic PDE $ \nabla^2 u = f(x, y) $, with homogeneous Dirichlet boundary conditions on the unit square.
# Discretize the interval $(0, 1)$ into $m+2$ equally spaced points $x_j$, $j=0, 1, \ldots, m+1$. The separation between points is $h = 1/(m+1)$.
# The 5-point stencil applied to the problem, with equal spacing in $x$ and $y$, is given by $$ \frac{1}{h^2}\left(u_{i, j-1} + u_{i-1, j} - 4u_{ij} + u_{i+1, j} + u_{i,j+1}\right) = f_{ij},$$
# for $i=1,\ldots, m$ and $j=1,\ldots, m$.
#
# ## A
# Reformulate the equation for the unknown values of $U_j$ as a linear system of equation in matrix form (i.e., $AU = F$). Make sure to specify the shape and structure of the matrix $A$, the unknown vector $U$, and the right hand side $F$.
#
# ## B
# Show that the Gauss-Seidel iterations for $AU=F$ will converge to the solution $U = A^{-1}F$.

# %% [markdown]
# # Q5: Nonlinear problems
# Describe in detail (but without actual code) a general algorithm for solving
# $$ u''(x) + f(u) = 0, \quad x\in (a, b), $$
# with homogeneous Dirichlet boundary conditions $u(a)=u(b)=0$. You may assume that $f$ is a sufficiently smooth, bounded, and continuous function.

# %% [markdown]
# # Q6: Linear operators
# Show that the differential operator $\mathcal{L} = \frac{d}{dx}\left(\kappa(x)\frac{d}{dx}\right)$ is self adjoint with respect to the inner product
# $$ \langle u, v\rangle = \int_a^bu(x)v(x)dx.$$
